# %% [markdown]
# ## PRE-PROCESSING
# ### Imports

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# - Renaming columns to match each other
# - Merging files together into a new csv file
# - Cleaning Nan from needed files

# %%
SteamSpy_x = pd.read_csv('steamspy_data.csv')
SteamApp_y = pd.read_csv('steam_app_data.csv')

# Rename columns to match wording of both files to avoid conflicts
SteamSpy_x.rename(columns={'appid': 'appid', 'name': 'name', 'price': 'price'}, inplace=True)
SteamApp_y.rename(columns={'steam_appid': 'appid', 'name': 'name', 'price_overview': 'price'}, inplace=True)

# Drop NaN values from needed categories in both dataframes
SteamSpy_x.dropna(subset=['appid', 'name', 'price', 'ccu'], inplace=True)
SteamApp_y.dropna(subset=['appid', 'name', 'price'], inplace=True)

# Convert data types to reduce memory usage
SteamSpy_x['appid'] = SteamSpy_x['appid'].astype('int32')
SteamSpy_x['ccu'] = SteamSpy_x['ccu'].astype('int32')
SteamSpy_x['price'] = SteamSpy_x['price'].astype('float32')

SteamApp_y['appid'] = SteamApp_y['appid'].astype('int32')

# Merging the two dataframes
# Please note if there are overlapping columns they will be suffixed with '_x' and '_y' respectively
merged_df = pd.merge(SteamSpy_x[['appid', 'name', 'price', 'ccu']], SteamApp_y, on='appid', how='inner')
merged_df = merged_df[merged_df['ccu'] > 1000]

label_encoder = LabelEncoder()

# Encoding categorical variables to numeric values
if 'name_x' in merged_df.columns:
    merged_df['name_x'] = label_encoder.fit_transform(merged_df['name_x'])
if 'name_y' in merged_df.columns:
    merged_df['name_y'] = label_encoder.fit_transform(merged_df['name_y'])


merged_df.to_csv('merged_steam_data.csv', index=False)

# Displaying pandas table of the merged dataframe
merged_df
# Out:
# C:\Users\desti\AppData\Local\Temp\ipykernel_21764\2647166148.py:2: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   SteamApp_y = pd.read_csv('steam_app_data.csv')
#          appid  name_x  price_x    ccu  type  name_y required_age is_free  \
# 0           10      52    999.0  16360  game      52          0.0   False
# 9          220     140    999.0   1177  game     140          0.0   False
# 10         240      53    999.0   7752  game      53          0.0   False
# 19         550     164    999.0  20328  game     164          0.0   False
# 20         620     225    199.0   2793  game     225          0.0   False
# ...        ...     ...      ...    ...   ...     ...          ...     ...
# 41330  1593500     129   4999.0  12509  game     129           18   False
# 43062  1677740     274    799.0   4423  game     274            0   False
# 45374  1794680     319    299.0  52451  game     319          0.0   False
# 46038  1832640     184    199.0   3505  game     184          0.0   False
# 46198  1843760     245   1499.0   2858  game     245          0.0   False
#
#       controller_support                                                dlc  \
# 0                    NaN                                                NaN
# 9                    NaN                                           [323140]
# 10                   NaN                                                NaN
# 19                  full                                                NaN
# 20                  full                                           [323180]
# ...                  ...                                                ...
# 41330               full                                                NaN
# 43062                NaN                                                NaN
# 45374               full                                                NaN
# 46038                NaN  [1881490, 1858303, 1858305, 1867630, 1858300, ...
# 46198                NaN                                          [1867020]
#
#        ...                                         categories  \
# 0      ...  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 9      ...  [{'id': 2, 'description': 'Single-player'}, {'...
# 10     ...  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 19     ...  [{'id': 2, 'description': 'Single-player'}, {'...
# 20     ...  [{'id': 2, 'description': 'Single-player'}, {'...
# ...    ...                                                ...
# 41330  ...  [{'id': 2, 'description': 'Single-player'}, {'...
# 43062  ...  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 45374  ...  [{'id': 2, 'description': 'Single-player'}, {'...
# 46038  ...  [{'id': 2, 'description': 'Single-player'}, {'...
# 46198  ...  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres  \
# 0                 [{'id': '1', 'description': 'Action'}]
# 9                 [{'id': '1', 'description': 'Action'}]
# 10                [{'id': '1', 'description': 'Action'}]
# 19                [{'id': '1', 'description': 'Action'}]
# 20     [{'id': '1', 'description': 'Action'}, {'id': ...
# ...                                                  ...
# 41330  [{'id': '1', 'description': 'Action'}, {'id': ...
# 43062  [{'id': '1', 'description': 'Action'}, {'id': ...
# 45374  [{'id': '1', 'description': 'Action'}, {'id': ...
# 46038  [{'id': '25', 'description': 'Adventure'}, {'i...
# 46198  [{'id': '4', 'description': 'Casual'}, {'id': ...
#
#                                              screenshots  \
# 0      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 9      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 10     [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 19     [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 20     [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# ...                                                  ...
# 41330  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 43062  [{'id': 16, 'path_thumbnail': 'https://cdn.aka...
# 45374  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 46038  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 46198  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                   movies    recommendations  \
# 0                                                    NaN  {'total': 118156}
# 9      [{'id': 904, 'name': 'Half-Life 2 Trailer', 't...  {'total': 103743}
# 10                                                   NaN   {'total': 87660}
# 19     [{'id': 5952, 'name': 'Left 4 Dead - The Sacri...  {'total': 418847}
# 20     [{'id': 81613, 'name': 'Portal 2 - Perpetual T...  {'total': 227268}
# ...                                                  ...                ...
# 41330  [{'id': 256864004, 'name': 'Features Trailer',...   {'total': 19841}
# 43062  [{'id': 256856802, 'name': 'Stumble Guys out o...    {'total': 1046}
# 45374  [{'id': 256858285, 'name': 'Early Access', 'th...   {'total': 10451}
# 46038  [{'id': 256870130, 'name': 'CG_montage-en', 't...   {'total': 19422}
# 46198  [{'id': 256867439, 'name': 'Rogue Tower Traile...     {'total': 577}
#
#                                             achievements  \
# 0                                                    NaN
# 9      {'total': 33, 'highlighted': [{'name': 'Defian...
# 10     {'total': 147, 'highlighted': [{'name': 'Someo...
# 19     {'total': 101, 'highlighted': [{'name': 'CL0WN...
# 20     {'total': 51, 'highlighted': [{'name': 'Wake U...
# ...                                                  ...
# 41330  {'total': 37, 'highlighted': [{'name': 'Father...
# 43062                                                NaN
# 45374  {'total': 37, 'highlighted': [{'name': 'Wings'...
# 46038  {'total': 1, 'highlighted': [{'name': 'Heros o...
# 46198  {'total': 48, 'highlighted': [{'name': 'Goblin...
#
#                                          release_date  \
# 0       {'coming_soon': False, 'date': '1 Nov, 2000'}
# 9      {'coming_soon': False, 'date': '16 Nov, 2004'}
# 10      {'coming_soon': False, 'date': '1 Nov, 2004'}
# 19     {'coming_soon': False, 'date': '16 Nov, 2009'}
# 20     {'coming_soon': False, 'date': '18 Apr, 2011'}
# ...                                               ...
# 41330  {'coming_soon': False, 'date': '14 Jan, 2022'}
# 43062   {'coming_soon': False, 'date': '7 Oct, 2021'}
# 45374  {'coming_soon': False, 'date': '17 Dec, 2021'}
# 46038  {'coming_soon': False, 'date': '20 Jan, 2022'}
# 46198  {'coming_soon': False, 'date': '28 Jan, 2022'}
#
#                                             support_info  \
# 0      {'url': 'http://steamcommunity.com/app/10', 'e...
# 9      {'url': 'http://steamcommunity.com/app/220', '...
# 10     {'url': 'http://steamcommunity.com/app/240', '...
# 19     {'url': 'http://steamcommunity.com/app/550', '...
# 20     {'url': 'http://steamcommunity.com/app/620', '...
# ...                                                  ...
# 41330  {'url': 'https://support.sms.playstation.com/h...
# 43062     {'url': '', 'email': 'support@kitkagames.com'}
# 45374         {'url': '', 'email': 'support@poncle.net'}
# 46038       {'url': '', 'email': 'support@mirror-2.com'}
# 46198  {'url': '', 'email': 'dieofdeathgames@gmail.com'}
#
#                                               background  \
# 0      https://cdn.akamai.steamstatic.com/steam/apps/...
# 9      https://cdn.akamai.steamstatic.com/steam/apps/...
# 10     https://cdn.akamai.steamstatic.com/steam/apps/...
# 19     https://cdn.akamai.steamstatic.com/steam/apps/...
# 20     https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                  ...
# 41330  https://cdn.akamai.steamstatic.com/steam/apps/...
# 43062  https://cdn.akamai.steamstatic.com/steam/apps/...
# 45374  https://cdn.akamai.steamstatic.com/steam/apps/...
# 46038  https://cdn.akamai.steamstatic.com/steam/apps/...
# 46198  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                      content_descriptors
# 0      {'ids': [2, 5], 'notes': 'Includes intense vio...
# 9                             {'ids': [], 'notes': None}
# 10     {'ids': [2, 5], 'notes': 'Includes intense vio...
# 19     {'ids': [2, 5], 'notes': 'Left 4 Dead 2 featur...
# 20                            {'ids': [], 'notes': None}
# ...                                                  ...
# 41330  {'ids': [2, 5], 'notes': 'Gameplay consists of...
# 43062                         {'ids': [], 'notes': None}
# 45374                         {'ids': [], 'notes': None}
# 46038                         {'ids': [], 'notes': None}
# 46198                         {'ids': [], 'notes': None}
#
# [339 rows x 42 columns]
